# %%
using LightGBM
using DelimitedFiles

LIGHTGBM_SOURCE = abspath("../LightGBM-3.3.5")

# Load LightGBM's binary classification example.
binary_test = readdlm(joinpath(LIGHTGBM_SOURCE, "examples", "binary_classification", "binary.test"), '\t')
binary_train = readdlm(joinpath(LIGHTGBM_SOURCE, "examples", "binary_classification", "binary.train"), '\t')
X_train = binary_train[:, 2:end]
y_train = binary_train[:, 1]
X_test = binary_test[:, 2:end]
y_test = binary_test[:, 1]

# Create an estimator with the desired parameters—leave other parameters at the default values.
estimator = LGBMClassification(
    objective = "binary",
    num_iterations = 100,
    learning_rate = .1,
    early_stopping_round = 5,
    feature_fraction = .8,
    bagging_fraction = .9,
    bagging_freq = 1,
    num_leaves = 1000,
    num_class = 1,
    metric = ["auc", "binary_logloss"]
)

# Fit the estimator on the training data and return its scores for the test data.
fit!(estimator, X_train, y_train, (X_test, y_test))

# Predict arbitrary data with the estimator.
predict(estimator, X_train)
# Out:
# [LightGBM] [Info] Number of positive: 3716, number of negative: 3284
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002265 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6132
# [LightGBM] [Info] Number of data points in the train set: 7000, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.530857 -> initscore=0.123586
# [LightGBM] [Info] Start training from score 0.123586
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 1, test_1's auc: 0.7224184081527347,
# Iteration: 1, test_1's binary_logloss: 0.6672355828476975
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 2, test_1's auc: 0.7365437951496389,
# Iteration: 2, test_1's binary_logloss: 0.6548998688529941
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 3, test_1's auc: 0.74468685500516,
# Iteration: 3, test_1's binary_logloss: 0.6438174499067784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 4, test_1's auc: 0.7829108617131063,
# Iteration: 4, test_1's binary_logloss: 0.6256971477706849
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 5, test_1's auc: 0.7844910990712074,
# Iteration: 5, test_1's binary_logloss: 0.6169980822636008
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 6, test_1's auc: 0.7897478070175439,
# Iteration: 6, test_1's binary_logloss: 0.6065809073394036
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 7, test_1's auc: 0.7880224458204335,
# Iteration: 7, test_1's binary_logloss: 0.6002182785690252
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 8, test_1's auc: 0.7901670536635707,
# Iteration: 8, test_1's binary_logloss: 0.5925991712141098
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 9, test_1's auc: 0.7929889060887513,
# Iteration: 9, test_1's binary_logloss: 0.5842167752967018
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 10, test_1's auc: 0.7916666666666666,
# Iteration: 10, test_1's binary_logloss: 0.5794911915732123
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 11, test_1's auc: 0.7986648606811145,
# Iteration: 11, test_1's binary_logloss: 0.570888121635174
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 12, test_1's auc: 0.8019865841073271,
# Iteration: 12, test_1's binary_logloss: 0.564352814624206
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 13, test_1's auc: 0.798890608875129,
# Iteration: 13, test_1's binary_logloss: 0.563418850871059
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 14, test_1's auc: 0.8029702012383901,
# Iteration: 14, test_1's binary_logloss: 0.5575412685491726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 15, test_1's auc: 0.8070336687306502,
# Iteration: 15, test_1's binary_logloss: 0.5517759906554937
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 16, test_1's auc: 0.8087912796697626,
# Iteration: 16, test_1's binary_logloss: 0.5477301036010563
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 17, test_1's auc: 0.8127418730650154,
# Iteration: 17, test_1's binary_logloss: 0.5439299165246737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 18, test_1's auc: 0.8123387512899897,
# Iteration: 18, test_1's binary_logloss: 0.5422397951754929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 19, test_1's auc: 0.8144672342621259,
# Iteration: 19, test_1's binary_logloss: 0.538438984817216
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 20, test_1's auc: 0.8143866099071208,
# Iteration: 20, test_1's binary_logloss: 0.5367390001111155
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 21, test_1's auc: 0.8171278379772962,
# Iteration: 21, test_1's binary_logloss: 0.5335058495602916
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 22, test_1's auc: 0.8148864809081527,
# Iteration: 22, test_1's binary_logloss: 0.5332798427468618
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 23, test_1's auc: 0.8179663312693498,
# Iteration: 23, test_1's binary_logloss: 0.5285669014736275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 24, test_1's auc: 0.8178373323013416,
# Iteration: 24, test_1's binary_logloss: 0.5282639790748312
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 25, test_1's auc: 0.8168537151702786,
# Iteration: 25, test_1's binary_logloss: 0.5291524421622322
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 26, test_1's auc: 0.814483359133127,
# Iteration: 26, test_1's binary_logloss: 0.5295001223082485
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 27, test_1's auc: 0.8149187306501547,
# Iteration: 27, test_1's binary_logloss: 0.5275527215647977
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping at iteration 28, the best iteration round is 23
# 7000×1 Matrix{Float64}:
#  0.8618890446596
#  0.8381473816945575
#  0.9298722289556586
#  0.45943882130333724
#  0.6725514207064556
#  0.08147839610372432
#  0.8550765165160386
#  0.9572544729363037
#  0.8197341486751601
#  0.9506474812125634
#  ⋮
#  0.922930677778771
#  0.1970049568539398
#  0.8287868785691274
#  0.8127550270488795
#  0.6029616645763142
#  0.3493224642559177
#  0.11324811937134613
#  0.18694614761919567
#  0.7441991052332468

# %%
# Cross-validate using a two-fold cross-validation iterable providing training indices.
splits = (collect(1:3500), collect(3501:7000))
cv(estimator, X_train, y_train, splits)
# Out:
# Cross-validation: 1
# [LightGBM] [Info] Number of positive: 1860, number of negative: 1640
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002365 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6132
# [LightGBM] [Info] Number of data points in the train set: 3500, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.531429 -> initscore=0.125880
# [LightGBM] [Info] Start training from score 0.125880
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 1, validation's auc: 0.6643102661716587,
# Iteration: 1, validation's binary_logloss: 0.6762830351464394
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 2, validation's auc: 0.690786015238275,
# Iteration: 2, validation's binary_logloss: 0.6653903118693901
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 3, validation's auc: 0.7014937088367312,
# Iteration: 3, validation's binary_logloss: 0.6553398719078511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 4, validation's auc: 0.7281074335095226,
# Iteration: 4, validation's binary_logloss: 0.6415788367116529
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 5, validation's auc: 0.7368574138455407,
# Iteration: 5, validation's binary_logloss: 0.6326239104410488
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 6, validation's auc: 0.7371482769108146,
# Iteration: 6, validation's binary_logloss: 0.6267807117467676
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 7, validation's auc: 0.7411892251866767,
# Iteration: 7, validation's binary_logloss: 0.6201841619469044
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 8, validation's auc: 0.7444721269611545,
# Iteration: 8, validation's binary_logloss: 0.6135848583931243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 9, validation's auc: 0.7470956298766676,
# Iteration: 9, validation's binary_logloss: 0.6076158156361404
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 10, validation's auc: 0.7467521656598708,
# Iteration: 10, validation's binary_logloss: 0.6047701864931496
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 11, validation's auc: 0.7489270020555415,
# Iteration: 11, validation's binary_logloss: 0.6004763683926357
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 12, validation's auc: 0.750529616578572,
# Iteration: 12, validation's binary_logloss: 0.5965850983641041
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 13, validation's auc: 0.7506466172707442,
# Iteration: 13, validation's binary_logloss: 0.5949966165922764
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 14, validation's auc: 0.7507724667547613,
# Iteration: 14, validation's binary_logloss: 0.5932194918383806
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 15, validation's auc: 0.7526923268520849,
# Iteration: 15, validation's binary_logloss: 0.5906127842650387
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 16, validation's auc: 0.7528089998112257,
# Iteration: 16, validation's binary_logloss: 0.5893237793063715
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 17, validation's auc: 0.7526772511326454,
# Iteration: 17, validation's binary_logloss: 0.5886257963731862
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 18, validation's auc: 0.7522410384679923,
# Iteration: 18, validation's binary_logloss: 0.588143329688346
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 19, validation's auc: 0.7523216607936908,
# Iteration: 19, validation's binary_logloss: 0.5875321803345608
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 20, validation's auc: 0.7535988364166457,
# Iteration: 20, validation's binary_logloss: 0.5860972225472895
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 21, validation's auc: 0.7536168617333668,
# Iteration: 21, validation's binary_logloss: 0.5857304946989161
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 22, validation's auc: 0.7547321372388623,
# Iteration: 22, validation's binary_logloss: 0.5847918970441024
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 23, validation's auc: 0.7538266108733954,
# Iteration: 23, validation's binary_logloss: 0.5854540561787128
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 24, validation's auc: 0.7538574177783371,
# Iteration: 24, validation's binary_logloss: 0.5853302972391805
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 25, validation's auc: 0.752883722942361,
# Iteration: 25, validation's binary_logloss: 0.586143934096658
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 26, validation's auc: 0.7525065022233409,
# Iteration: 26, validation's binary_logloss: 0.5864773492759536
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping at iteration 27, the best iteration round is 22
#
# Cross-validation: 2
# [LightGBM] [Info] Number of positive: 1856, number of negative: 1644
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000727 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6132
# [LightGBM] [Info] Number of data points in the train set: 3500, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.530286 -> initscore=0.121291
# [LightGBM] [Info] Start training from score 0.121291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 1, validation's auc: 0.6684805271439811,
# Iteration: 1, validation's binary_logloss: 0.6753954981854776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 2, validation's auc: 0.6934597102019407,
# Iteration: 2, validation's binary_logloss: 0.6639879175294601
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 3, validation's auc: 0.7019880999213218,
# Iteration: 3, validation's binary_logloss: 0.654268064387275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 4, validation's auc: 0.7234103724101757,
# Iteration: 4, validation's binary_logloss: 0.6416804448888482
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 5, validation's auc: 0.7343413978494624,
# Iteration: 5, validation's binary_logloss: 0.6324283673172719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 6, validation's auc: 0.7380950039339103,
# Iteration: 6, validation's binary_logloss: 0.6261455868532654
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 7, validation's auc: 0.7409726593233674,
# Iteration: 7, validation's binary_logloss: 0.6197859734632528
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 8, validation's auc: 0.7474334513506425,
# Iteration: 8, validation's binary_logloss: 0.6121716503439448
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 9, validation's auc: 0.749516456858117,
# Iteration: 9, validation's binary_logloss: 0.6067100827543481
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 10, validation's auc: 0.7510962496721741,
# Iteration: 10, validation's binary_logloss: 0.602075141231912
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 11, validation's auc: 0.7521331628638867,
# Iteration: 11, validation's binary_logloss: 0.5984245328462976
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 12, validation's auc: 0.7555169813794912,
# Iteration: 12, validation's binary_logloss: 0.593808679156848
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 13, validation's auc: 0.7560539601363756,
# Iteration: 13, validation's binary_logloss: 0.5915506585005705
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 14, validation's auc: 0.7573941122475741,
# Iteration: 14, validation's binary_logloss: 0.5890699923842673
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 15, validation's auc: 0.758232035142932,
# Iteration: 15, validation's binary_logloss: 0.5870159002262236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 16, validation's auc: 0.7598098610018358,
# Iteration: 16, validation's binary_logloss: 0.5844339876751554
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 17, validation's auc: 0.7610814975085235,
# Iteration: 17, validation's binary_logloss: 0.58288753995946
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 18, validation's auc: 0.7612827825858903,
# Iteration: 18, validation's binary_logloss: 0.581809940489617
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 19, validation's auc: 0.7630032126934173,
# Iteration: 19, validation's binary_logloss: 0.5792347070550797
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 20, validation's auc: 0.7625157356412274,
# Iteration: 20, validation's binary_logloss: 0.5791979562843259
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 21, validation's auc: 0.7623698531340152,
# Iteration: 21, validation's binary_logloss: 0.5789353719493936
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 22, validation's auc: 0.7612526226068712,
# Iteration: 22, validation's binary_logloss: 0.5795671929144831
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration: 23, validation's auc: 0.761277209546289,
# Iteration: 23, validation's binary_logloss: 0.5793980148086791
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping at iteration 24, the best iteration round is 19
#
# Cross-validation finished
# - validation's binary_logloss mean: 0.5829376820423164, std: 0.0050058454080974465
# - validation's auc mean: 0.756891855884815, std: 0.0062018266238590735
# Dict{String, Dict{String, Vector{Float64}}} with 1 entry:
#   "validation" => Dict("binary_logloss"=>[0.586477, 0.579398], "auc"=>[0.752507…

# %%
# Exhaustive search on an iterable containing all combinations of learning_rate ∈ {.1, .2} and
# bagging_fraction ∈ {.8, .9}
params = [Dict(:learning_rate => learning_rate,
               :bagging_fraction => bagging_fraction) for
          learning_rate in (.1, .2),
          bagging_fraction in (.8, .9)]
search_cv(estimator, X_train, y_train, splits, params)

# Save and load the fitted model.
filename = pwd() * "/finished.model"
savemodel(estimator, filename)
loadmodel!(estimator, filename)
# Out:
# Search: 1
# Dict(:learning_rate => 0.1, :bagging_fraction => 0.8)
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001477 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000605 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# - validation's binary_logloss mean: 0.578013940413016, std: 0.0022481713012254666
# - validation's auc mean: 0.7630972141334994, std: 0.001964220425692013
#
# Search: 2
# Dict(:learning_rate => 0.2, :bagging_fraction => 0.8)
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001661 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001081 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# - validation's binary_logloss mean: 0.5947483595330175, std: 0.0040607141121178185
# - validation's auc mean: 0.750553104320484, std: 0.0046759408965666525
#
# Search: 3
# Dict(:learning_rate => 0.1, :bagging_fraction => 0.9)
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000903 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000984 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# - validation's binary_logloss mean: 0.5829376820423164, std: 0.0050058454080974465
# - validation's auc mean: 0.756891855884815, std: 0.0062018266238590735
#
# Search: 4
# Dict(:learning_rate => 0.2, :bagging_fraction => 0.9)
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001096 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000936 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# - validation's binary_logloss mean: 0.5990163712420007, std: 0.0022308426167908443
# - validation's auc mean: 0.7484074179085021, std: 0.0026175804242864757
#
# Search finished
